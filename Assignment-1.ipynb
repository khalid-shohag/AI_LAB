# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# # Generation of input data

# %%
X = np.arange(-10, 10, 0.1)
X[:5]
# Out:
# array([-10. ,  -9.9,  -9.8,  -9.7,  -9.6])

# %% [markdown]
# # y = wx + b; where 'w' and 'b' are constants

# %%
W = random.randint(-20, 20)
b = random.randint(-20, 20)
W, b

#Output
y = W*X + b
plt.plot(X, y)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %% [markdown]
# # y = x^2

# %%
y = np.power(X, 2)
plt.plot(X, y)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Quadratic Regression')
# Out:
# Text(0.5, 1.0, 'Quadratic Regression')

# %% [markdown]
# # y = 1/ (1 + e^(-x))

# %%
y = 1/(1 + np.exp(-X))
plt.plot(X, y)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Sigmoid')
# Out:
# Text(0.5, 1.0, 'Sigmoid Regression')

# %% [markdown]
# # y = (e^x - e^(-x)) / (e^x + e^(-x))

# %%
y = (np.exp(X) - np.exp(-X)) / (np.exp(X) + np.exp(-X))
plt.plot(X, y)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Hyperbolic Tangent')
# Out:
# Text(0.5, 1.0, 'Hyperbolic Tangent Regression')

# %% [markdown]
# # y = g(f(x)) where u = f(x) = wx + b and y = g(u) = 1/ (1 + e^(-u))

# %%
y = W*X + b
y = 1/(1 + np.exp(-y))
plt.plot(X, y)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Logistic Regression')
# Out:
# Text(0.5, 1.0, 'Logistic Regression')

# %% [markdown]
# # y = g(f(x)) where f(x) = wx + b, u = f(x), and g(u) = (e^u - e^(-u)) / (e^u - e^(-u))

# %%
y = W*X + b
y = (np.exp(y) - np.exp(-y)) / (np.exp(y) + np.exp(-y))
plt.plot(X, y)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Hyperbolic Tangent')
# Out:
# Text(0.5, 1.0, 'Hyperbolic Tangent Regression')

# %% [markdown]
# # y1 = g1(f1(x)) where f1(x) = w1x + b1, u1 = f1(x), and g1(u1) = 1/ (1 + e^(-u1))

# %%
w1 = random.randint(-20, 20)
b1 = random.randint(-20, 20)

y1 = w1*X+b1
y1 = 1/(1 + np.exp(-y1))
plt.plot(X, y)
plt.xlabel('X')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# # y2 = g2(f2(x)) where f2(x) = w2x + b2, u2 = f2(x), and g2(u2) = 1/ (1 + e^(-u2))

# %%
w2 = random.randint(-20, 20)
b2 = random.randint(-20, 20)
y2 = w2*X+b2
y2 = 1/(1 + np.exp(-y2))
plt.plot(X, y)

# %% [markdown]
# # y = g3(f3(v)) where f3(v) = w3y1 + w4y2 + b, w = f3(v), and g3(w) = 1/ (1 + e^(-w))

# %%
w3 = random.randint(-20, 20)
w4 = random.randint(-20, 20)
b = random.randint(-20, 20)
y = w3*y1 + w4*y2 + b
y = 1/(1 + np.exp(-y))
plt.plot(X, y)
plt.xlabel('X')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
